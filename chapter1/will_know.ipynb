# %% [markdown]
# $\varepsilon$-greedy 외 알고리즘 : Upper Confidence Bound 알고리즘, gradient bandit 알고리즘

# %% [markdown]
# 표본평균 : 균일한 가중치 사용, stationary problem 에 사용
# 지수 이동 평균 : 새로운 데이터 일수록 큰 가중치 부여, non stationary problem에 사용
#
#
# ![image.png](attachment:image.png)
